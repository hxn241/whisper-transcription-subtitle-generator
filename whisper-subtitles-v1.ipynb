# %% [markdown]
# # **📹 AUTOMATIC SUBTITLE TEST**

# %% [markdown]
# Prueba de subtitulado automático para cumplimiento de las directrices impuestas por la normativa UNE

# %%
# !pip install openai-whisper
# !pip install requests

# %%
import whisper
import math
import time
import requests
from urllib.parse import urlparse

# %%
# Load model
model = whisper.load_model("medium")

# %%
# Video file urls
media_links = [
  'http://corerepo.acceso.com/api/v2/temp_file/266436c09f1a5be02201bb233116133a/?format=json'
]

# %% [markdown]
# ### **Helper functions**

# %%
def get_audio_file(media_link):
  response = requests.get(media_link)
  if response.ok:
    audio = response.url

  audio_type = "video" if urlparse(audio).path.endswith("mp4") else "audio"
  return audio, audio_type

# %%
def format_transcription_by_segments(transcription):
  formatted_txt = ""
  for segment in transcription['segments']:
    text = segment['text']
    start_time = float(segment['start'])
    end_time = float(segment['end'])
    diff_secs = end_time-start_time
    cps = math.ceil(len(text.replace(" ", "").strip())/diff_secs)
    formatted_txt += f"{segment['id']}:: {start_time} --> {end_time} ({cps})\n{text}\n\n"
  return formatted_txt

# %%
def format_transcription_by_words(transcription):
  formatted_txt = ""
  for segment in transcription['segments']:
    for word in segment['words']:
      text = word['word']
      start_time = float(word['start'])
      end_time = float(word['end'])
      diff_secs = max(end_time-start_time, 1)
      cps = math.ceil(len(text.replace(" ", "").strip())/diff_secs)
      formatted_txt += f"{start_time} --> {end_time} ({cps})\n{text}\n"
      #formatted_txt = formatted_txt + f"{start_time} --> {end_time} ({cps})\n{text}\n"
  return formatted_txt

# %% [markdown]
# ### Retrieve audio file to be processed

# %%
audio, audio_type = get_audio_file(media_links[0])

# %% [markdown]
# ### Test transcription with prompt options
#
# Review:
#
#
# * [Prompting whisper](https://github.com/openai/openai-cookbook/blob/main/examples/Whisper_prompting_guide.ipynb)
# * [Api whisper prompting](https://platform.openai.com/docs/guides/speech-to-text/prompting)
# * [Misc prompt engineering whisper](https://medium.com/axinc-ai/prompt-engineering-in-whisper-6bb18003562d)

# %%
# options = dict(beam_size=5, best_of=5)
# transcribe_options = dict(task="transcribe", **options)
# transcription = model.transcribe(audio, **transcribe_options)

PROMPT = """
Genera subtítulos a partir de la trasncripción. Estos subtítulos deben cumplir los siguientes requerimientos impuestos por la norma UNE de subtitulado.
    - No romper sintagmas, deben ir en la misma línea:
        ejemplo: <incorrecto>artículo + sustantivo: el trabajo \n  duro </incorrecto>; <correcto>el trabajo duro </correcto>
        ejemplo: <incorrecto>sustantivo + adjetivo: de \n  manera urgente </incorrecto>; <correcto>de manera urgente<correcto>.
    - No separar verbos compuestos en líneas o subtítulos diferentes:
        ejemplo: </incorrecto>nosotros hemos \n  hecho</incorrecto>; <correcto>nosotros hemos hecho</correcto>.
    -  A final de línea, no pueden quedar determinantes:
        ejemplo: <incorrecto>este viernes en la \n  sede </incorrecto>. <correcto>este viernes en la sede. </correcto>.
    - El máximo de caracteres por línea será 37 caracteres.
    - El máximo de caracteres por segundo (cps) es de 15.
"""
# video = '/content/mda_206247965.mp4'
transcription = model.transcribe(audio)
# transcription = model.transcribe(video, initial_prompt=PROMPT)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
print(transcription)

# %%
txt = format_transcription_by_segments(transcription)
print(txt)

# %% [markdown]
# ### Test transcription with word detail options

# %%
transcription2 = model.transcribe(audio, word_timestamps=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:115: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
print(transcription2)
# Out:
# {'text': ' también liberado. Y arranca en Barcelona el Mobile, la gran feria de las telecomunicaciones. Se espera que el evento mueva 350 millones de euros, es mucho dinero pero no llega todavía las cifras pre pandemia. Y como es ya habitual, Aragonés y Colau plantaron al rey en la recepción pero luego Gabriela de Torres sí asistieron a la cena. Sí, buenos días. Como bien decís, una vez más se saltaron ese saludo protocolario como gesto de rechazo a la monarquía pero sí que participaron en el cóctel anterior y después en la cena inaugural. En su discurso el monarca quiso ensalzar el valor de esta feria en medio, dijo, de la inestabilidad internacional actual. Ha tenido el rey palabras de aliento para Ucrania en esta inauguración del Mobile y falta hacen en un momento crítico de esta conferencia.', 'segments': [{'id': 0, 'seek': 0, 'start': 0.0, 'end': 5.58, 'text': ' también liberado. Y arranca en Barcelona el Mobile, la gran feria de las', 'tokens': [50364, 6407, 6774, 1573, 13, 398, 50235, 496, 465, 21247, 806, 22625, 11, 635, 9370, 7202, 654, 368, 2439, 50637], 'temperature': 0.0, 'avg_logprob': -0.258345911325502, 'compression_ratio': 1.4724137931034482, 'no_speech_prob': 0.3613327145576477, 'words': [{'word': ' también', 'start': 0.0, 'end': 0.5, 'probability': 0.10316583514213562}, {'word': ' liberado.', 'start': 0.5, 'end': 2.06, 'probability': 0.7870670557022095}, {'word': ' Y', 'start': 3.12, 'end': 3.2, 'probability': 0.692878246307373}, {'word': ' arranca', 'start': 3.2, 'end': 3.44, 'probability': 0.9626889824867249}, {'word': ' en', 'start': 3.44, 'end': 3.64, 'probability': 0.9893892407417297}, {'word': ' Barcelona', 'start': 3.64, 'end': 4.0, 'probability': 0.943720281124115}, {'word': ' el', 'start': 4.0, 'end': 4.36, 'probability': 0.853016197681427}, {'word': ' Mobile,', 'start': 4.36, 'end': 4.62, 'probability': 0.43438470363616943}, {'word': ' la', 'start': 4.84, 'end': 4.84, 'probability': 0.9772546291351318}, {'word': ' gran', 'start': 4.84, 'end': 5.04, 'probability': 0.9822177290916443}, {'word': ' feria', 'start': 5.04, 'end': 5.24, 'probability': 0.9806984066963196}, {'word': ' de', 'start': 5.24, 'end': 5.4, 'probability': 0.9967857599258423}, {'word': ' las', 'start': 5.4, 'end': 5.58, 'probability': 0.9746871590614319}]}, {'id': 1, 'seek': 0, 'start': 5.58, 'end': 9.94, 'text': ' telecomunicaciones. Se espera que el evento mueva 350 millones de euros, es', 'tokens': [50637, 4304, 1112, 409, 299, 9188, 13, 1100, 37862, 631, 806, 40655, 49532, 2757, 18065, 22416, 368, 14160, 11, 785, 50857], 'temperature': 0.0, 'avg_logprob': -0.258345911325502, 'compression_ratio': 1.4724137931034482, 'no_speech_prob': 0.3613327145576477, 'words': [{'word': ' telecomunicaciones.', 'start': 5.58, 'end': 6.34, 'probability': 0.9876870393753052}, {'word': ' Se', 'start': 6.72, 'end': 6.8, 'probability': 0.9911966323852539}, {'word': ' espera', 'start': 6.8, 'end': 6.96, 'probability': 0.9976843595504761}, {'word': ' que', 'start': 6.96, 'end': 7.12, 'probability': 0.9802123308181763}, {'word': ' el', 'start': 7.12, 'end': 7.24, 'probability': 0.9972946047782898}, {'word': ' evento', 'start': 7.24, 'end': 7.44, 'probability': 0.9983295798301697}, {'word': ' mueva', 'start': 7.44, 'end': 7.98, 'probability': 0.981902003288269}, {'word': ' 350', 'start': 7.98, 'end': 8.8, 'probability': 0.9404993653297424}, {'word': ' millones', 'start': 8.8, 'end': 9.3, 'probability': 0.9943302869796753}, {'word': ' de', 'start': 9.3, 'end': 9.52, 'probability': 0.996156632900238}, {'word': ' euros,', 'start': 9.52, 'end': 9.72, 'probability': 0.9848176836967468}, {'word': ' es', 'start': 9.8, 'end': 9.94, 'probability': 0.9627674221992493}]}, {'id': 2, 'seek': 0, 'start': 9.94, 'end': 13.84, 'text': ' mucho dinero pero no llega todavía las cifras pre pandemia. Y como es ya', 'tokens': [50857, 9824, 27923, 4768, 572, 40423, 28388, 2439, 269, 351, 3906, 659, 33245, 13, 398, 2617, 785, 2478, 51052], 'temperature': 0.0, 'avg_logprob': -0.25 ...

# %%
txt = format_transcription_by_words(transcription2)
print(txt)
txt
# Out:
# 0.0 --> 0.32 (1)
#  o
# 0.32 --> 0.58 (7)
#  también
# 0.58 --> 1.02 (6)
#  podría
# 1.02 --> 1.44 (5)
#  estar
# 1.44 --> 1.74 (3)
#  más
# 1.74 --> 2.12 (6)
#  cerca.
# 5.66 --> 5.86 (2)
#  El
# 5.86 --> 6.1 (3)
#  rey
# 6.1 --> 6.36 (6)
#  Felipe
# 6.36 --> 6.62 (2)
#  VI
# 6.62 --> 6.82 (2)
#  ha
# 6.82 --> 7.14 (9)
#  presidido
# 7.14 --> 7.32 (2)
#  la
# 7.32 --> 7.46 (4)
#  cena
# 7.46 --> 7.8 (9)
#  inaugural
# 7.8 --> 8.02 (2)
#  en
# 8.02 --> 8.1 (2)
#  el
# 8.1 --> 8.36 (8)
#  Congreso
# 8.36 --> 8.68 (7)
#  Mundial
# 8.68 --> 8.88 (2)
#  de
# 8.88 --> 9.32 (8)
#  Móviles,
# 9.6 --> 9.82 (5)
#  donde
# 9.82 --> 9.98 (2)
#  ha
# 9.98 --> 10.54 (10)
#  codificado
# 10.54 --> 10.74 (3)
#  con
# 10.74 --> 10.94 (2)
#  el
# 10.94 --> 11.42 (10)
#  presidente
# 11.42 --> 11.68 (3)
#  del
# 11.68 --> 12.0 (9)
#  gobierno,
# 12.06 --> 12.28 (5)
#  Pedro
# 12.28 --> 12.66 (8)
#  Sánchez,
# 12.68 --> 12.8 (1)
#  y
# 12.8 --> 12.9 (2)
#  el
# 12.9 --> 13.04 (2)
#  de
# 13.04 --> 13.24 (2)
#  la
# 13.24 --> 13.78 (12)
#  Generalitat,
# 13.96 --> 14.02 (4)
#  Pera
# 14.02 --> 14.38 (9)
#  Aragonés.
# 18.88 --> 19.12 (7)
#  También
# 19.12 --> 19.36 (6)
#  estuvo
# 19.36 --> 19.5 (2)
#  la
# 19.5 --> 19.8 (9)
#  alcaldesa
# 19.8 --> 19.92 (2)
#  de
# 19.92 --> 20.3 (10)
#  Barcelona,
# 20.38 --> 20.54 (3)
#  Ada
# 20.54 --> 20.78 (6)
#  Colau,
# 20.82 --> 20.94 (2)
#  ni
# 20.94 --> 21.56 (8)
#  Aragonés
# 21.56 --> 21.8 (2)
#  ni
# 21.8 --> 22.04 (4)
#  ella
# 22.04 --> 22.42 (9)
#  quisieron
# 22.42 --> 22.86 (7)
#  recibir
# 22.86 --> 23.0 (1)
#  o
# 23.0 --> 23.28 (5)
#  posar
# 23.28 --> 23.48 (3)
#  con
# 23.48 --> 23.8 (6)
#  Felipe
# 23.8 --> 24.16 (3)
#  VI.
# 24.68 --> 24.94 (5)
#  Desde
# 24.94 --> 25.26 (3)
#  hoy
# 25.26 --> 25.54 (5)
#  hasta
# 25.54 --> 25.72 (2)
#  el
# 25.72 --> 26.0 (7)
#  jueves,
# 26.08 --> 26.18 (2)
#  la
# 26.18 --> 26.46 (7)
#  capital
# 26.46 --> 27.0 (8)
#  catalana
# 27.0 --> 27.26 (5)
#  acoge
# 27.26 --> 27.42 (2)
#  el
# 27.42 --> 27.66 (7)
#  Mobile,
# 27.82 --> 27.98 (3)
#  una
# 27.98 --> 28.58 (5)
#  feria
# 28.58 --> 28.88 (3)
#  que
# 28.88 --> 29.04 (2)
#  ya
# 29.04 --> 29.16 (2)
#  es
# 29.16 --> 29.48 (3)
#  más
# 29.48 --> 29.72 (2)
#  de
# 29.72 --> 30.28 (10)
#  tecnología
# 30.28 --> 30.52 (3)
#  que
# 30.52 --> 30.7 (4)
#  solo
# 30.7 --> 30.96 (2)
#  de
# 30.96 --> 31.44 (8)
#  móviles.
# 31.7 --> 31.8 (2)
#  En
# 31.8 --> 31.96 (4)
#  esta
# 31.96 --> 32.42 (7)
#  edición
# 32.42 --> 32.88 (7)
#  todavía
# 32.88 --> 33.1 (2)
#  no
# 33.1 --> 33.26 (2)
#  va
# 33.26 --> 33.4 (1)
#  a
# 33.4 --> 33.52 (6)
#  llegar
# 33.52 --> 33.66 (1)
#  a
# 33.66 --> 33.84 (3)
#  las
# 33.84 --> 34.14 (6)
#  cifras
# 34.14 --> 34.4 (2)
#  de
# 34.4 --> 34.56 (5)
#  antes
# 34.56 --> 34.72 (2)
#  de
# 34.72 --> 34.88 (2)
#  la
# 34.88 --> 35.28 (9)
#  pandemia.
# 37.24 --> 37.4 (3)
#  Con
# 37.4 --> 37.58 (2)
#  el
# 37.58 --> 37.84 (6)
#  Cártel
# 37.84 --> 38.04 (2)
#  de
# 38.04 --> 38.36 (8)
#  Completo
# 38.36 --> 38.64 (5)
#  desde
# 38.64 --> 38.92 (4)
#  hace
# 38.92 --> 39.16 (6)
#  varias
# 39.16 --> 39.64 (8)
#  semanas,
# 39.92 --> 39.98 (4)
#  para
# 39.98 --> 40.2 (4)
#  esas
# 40.2 --> 40.4 (6)
#  fechas
# 40.4 --> 40.74 (7)
#  estamos
# 40.74 --> 41.34 (10)
#  completos.
# 41.5 --> 41.82 (9)
#  Barcelona
# 41.82 --> 42.08 (2)
#  se
# 42.08 --> 42.34 (7)
#  prepara
# 42.34 --> 42.66 (4)
#  para
# 42.66 --> 42.94 (7)
#  recibir
# 42.94 --> 43.14 (2)
#  la
# 43.14 --> 43.26 (5)
#  nueva
# 43.26 --> 43.58 (7)
#  edición
# 43.58 --> 43.8 (3)
#  del
# 43.8 --> 44.1 (7)
#  Mobile.
# 44.24 --> 44.36 (7)
#  Puestas
# 44.36 --> 44.62 (1)
#  a
# 44.62 --> 45.02 (6)
#  punto,
# 45.5 --> 45.84 (8)
#  personal
# 45.84 --> 46.66 (10)
#  preparado.
# 46.76 --> 46.94 (5)
#  Estos
# 46.94 --> 47.16 (4)
#  días
# 47.16 --> 47.4 (3)
#  las
# 47.4 --> 47.58 (6)
#  calles
# 47.58 --> 47.74 (2)
#  de
# 47.74 --> 47.84 (2)
#  la
# 47.84 --> 48.1 (6)
#  ciudad
# 48.1 --> 48.52 (8)
#  catalana
# 48.52 --> 48.72 (2)
#  se
# 48.72 --> 48.92 (6)
#  llenan
# 48.92 --> 49.26 (2)
#  de
# 49.26 --> 49.84 (13)
#  congresistas.
# 49.92 --> 49.96 (2)
#  El
# 49.96 --> 50.1 (5)
#  hotel
# 50.1 --> 50.32 (5)
#  tiene
# 50.32 --> 51.32 (3)
#  368
# 51.32 --> 52.12 (13)
#  habitaciones,
# 52.58 --> 52.76 (3)
#  las
# 52.76 --> 53.0 (7)
#  tenemos
# 53.0 --> 53.56 (7)
#  llenas,
# 53.72 --> 54.28 (9)
#  realmente
# 54.28 --> 54.8 (7)
#  llenas.
# 54.8 --> 55.08 (1)
#  Y
# 55.08 --> 55.28 (3)
#  los
# 55.28 --> 55.54 (7)
#  hoteles
# 55.54 --> 55.92 (6)
#  acogen
# 55.92 --> 56.2 (4)
#  esta
# 56.2 --> 56.48 (4)
#  cita
# 56.48 --> 57.04 (11)
#  empresarial
# 57.04 --> 57.28 (2)
#  en
# 57.28 --> 57.44 (2)
#  un
# 57.44 --> 57.54 (3)
#  mes
# 57.54 --> 57.76 (5)
#  donde
# 57.76 --> 57.96 (2)
#  el
# 57.96 --> 58.3 (7)
#  turismo
# 58.3 --> 58.62 (5)
#  suele
# 58.62 --> 58.84 (3)
#  ser
# 58.84 --> 59.22 (6)
#  menor.
# 59.5 --> 59.5 (4)
#  Para
# 59.5 --> 60.16 (8)
#  nosotros
# 60.16 --> 60.78 (10)
#  representa
# 60.78 --> 61.16 (4)
#  como
# 61.16 --> 61.48 (2)
#  un
# 61.48 --> 61.76 (6)
#  tercio
# 61.76 --> 61.9 (2)
#  de
# 61.9 --> 62.04 (2)
#  la
# 62.04 --> 62.58 (11)
#  facturación
# 62.58 --> 62.78 (3)
#  del
# 62.78 --> 63.0 (6)
#  primer
# 63.0 --> 63.46 (10)
#  trimestre.
# 63.72 --> 63.84 (2)
#  En
# 63.84 --> 63.98 (4)
#  este
# 63.98 --> 64.56 (11)
#  restaurante
# 64.56 --> 65.08 (9)
#  completan
# 65.08 --> 65.2 (1)
#  a
# 65.2 --> 65.38 (4)
#  foro
# 65.38 --> 65.44 (2)
#  en
# 65.44 --> 65.56 (4)
#  días
# 65.56 --> 65.7 (2)
#  de
# 65.7 --> 65.86 (2)
#  la
# 65.86 --> 66.1 (6)
#  semana
# 66.1 --> 66.38 (5)
#  donde
# 66.38 --> 66.64 (2)
#  no
# 66.64 --> 66.88 (6)
#  suelen
# 66.88 --> 67.16 (5)
#  tener
# 67.16 --> 67.52 (4)
#  casi
# 67.52 --> 68.2 (11)
#  comensales.
# 68.4 --> 68.92 (5)
#  Lunes
# 68.92 --> 69.5 (7)
#  cerrado
# 69.5 --> 69.66 (4)
#  para
# 69.66 --> 69.84 (3)
#  una
# 69.84 --> 70.26 (6)
#  marca,
# 70.66 --> 70.88 (6)
#  martes
# 70.88 --> 71.16 (4)
#  para
# 71.16 --> 71.42 (4)
#  otro
# 71.42 --> 72.0 (1)
#  y
# 72.0 --> 73.04 (9)
#  miércoles
# 73.04 --> 74.02 (13)
#  prácticamente
# 74.02 --> 74.4 (3)
#  100
# 74.4 --> 74.74 (1)
# %
# 74.74 --> 75.0 (2)
#  ya
# 75.0 --> 75.16 (2)
#  de
# 75.16 --> 75.52 (9)
#  ocupación
# 75.52 --> 75.92 (2)
#  de
# 75.92 --> 76.34 (9)
#  reservas.
# 76.42 --> 76.56 (1)
#  Y
# 76.56 --> 76.82 (7)
#  afirman
# 76.82 --> 76.98 (3)
#  que
# 76.98 --> 77.18 (2)
#  la
# 77.18 --> 77.32 (5)
#  media
# 77.32 --> 77.5 (3)
#  que
# 77.5 --> 77.68 (2)
#  se
# 77.68 --> 77.88 (5)
#  gasta
# 77.88 --> 78.08 (3)
#  por
# 78.08 --> 78.5 (7)
#  persona
# 78.5 --> 78.88 (2)
#  es
# 78.88 --> 79.28 (8)
#  bastante
# 79.28 --> 79.58 (3)
#  más
# 79.58 --> 79.98 (8)
#  elevada.
# 80.06 --> 80.5 (13)
#  Prácticamente
# 80.5 --> 80.76 (2)
#  se
# 80.76 --> 81.18 (8)
#  duplica,
# 81.52 --> 81.6 (8)
#  entonces
# 81.6 --> 82.5 (9)
#  imagínate
# 82.5 --> 83.38 (6)
#  llenar
# 83.38 --> 83.64 (4)
#  cada
# 83.64 --> 84.1 (3)
#  día
# 84.1 --> 84.82 (3)
#  con
# 84.82 --> 85.02 (2)
#  un
# 85.02 --> 85.34 (6)
#  perfil
# 85.34 --> 85.5 (3)
#  que
# 85.5 --> 85.86 (7)
#  duplica
# 85.86 --> 86.0 (2)
#  el
# 86.0 --> 86.32 (5)
#  gasto
# 86.32 --> 86.46 (5)
#  medio
# 86.46 --> 86.7 (3)
#  que
# 86.7 --> 87.02 (7)
#  tienes.
# 87.3 --> 87.6 (6)
#  Calles
# 87.6 --> 87.9 (7)
#  llenas,
# 88.08 --> 88.32 (6)
#  trenes
# 88.32 --> 88.42 (1)
#  y
# 88.42 --> 88.6 (5)
#  metro
# 88.6 --> 88.76 (1)
#  a
# 88.76 --> 89.22 (7)
#  rebosar
# 89.22 --> 89.54 (1)
#  y
# 89.54 --> 89.84 (8)
#  empresas
# 89.84 --> 90.12 (2)
#  de
# 90.12 --> 90.54 (10)
#  transporte
# 90.54 --> 90.76 (3)
#  que
# 90.76 --> 91.0 (7)
#  también
# 91.0 --> 91.26 (2)
#  se
# 91.26 --> 91.76 (11)
#  benefician.
# 91.8 --> 92.2 (5)
#  Puede
# 92.2 --> 92.84 (7)
#  suponer
# 92.84 --> 93.18 (5)
#  sobre
# 93.18 --> 93.34 (2)
#  un
# 93.34 --> 93.56 (2)
#  10
# 93.56 --> 94.42 (1)
# %
# 94.42 --> 94.78 (2)
#  de
# 94.78 --> 94.92 (2)
#  la
# 94.92 --> 95.5 (11)
#  facturación
# 95.5 --> 95.94 (6)
#  anual.
# 96.12 --> 96.26 (3)
#  Una
# 96.26 --> 96.56 (6)
#  semana
# 96.56 --> 96.82 (5)
#  donde
# 96.82 --> 97.28 (9)
#  Barcelona
# 97.28 --> 97.92 (8)
#  atenderá
# 97.92 --> 98.12 (1)
#  a
# 98.12 --> 98.24 (3)
#  más
# 98.24 --> 98.38 (2)
#  de
# 98.38 --> 98.58 (2)
#  80
# 98.58 --> 98.82 (4)
# .000
# 98.82 --> 99.68 (11)
#  visitantes.
# 101.36 --> 101.44 (3)
#  Muy
# 101.44 --> 101.74 (6)
#  buenos
# 101.74 --> 102.14 (5)
#  días,
# 102.24 --> 102.88 (9)
#  señorías.
# 103.12 --> 103.24 (3)
#  Hoy
# 103.24 --> 103.4 (3)
#  los
# 103.4 --> 103.8 (9)
#  diputados
# 103.8 --> 103.96 (2)
#  de
# 103.96 --> 104.16 (3)
#  Vox
# 104.16 --> 104.36 (3)
#  van
# 104.36 --> 104.56 (1)
#  a
# 104.56 --> 104.96 (9)
#  registrar
# 104.96 --> 105.06 (2)
#  en
# 105.06 --> 105.24 (2)
#  el
# 105.24 --> 105.44 (8)
#  Congreso
# 105.44 --> 105.58 (2)
#  la
# 105.58 --> 105.84 (6)
#  moción
# 105.84 --> 105.96 (2)
#  de
# 105.96 --> 105.96 (9)
#  sanación.
# '0.0 --> 0.32 (1)\n o\n0.32 --> 0.58 (7)\n también\n0.58 --> 1.02 (6)\n podría\n1.02 --> 1.44 (5)\n estar\n1.44 --> 1.74 (3)\n más\n1.74 --> 2.12 (6)\n cerca.\n5.66 --> 5.86 (2)\n El\n5.86 --> 6.1 (3)\n rey\n6.1 --> 6.36 (6)\n Felipe\n6.36 --> 6.62 (2)\n VI\n6.62 --> 6.82 (2)\n ha\n6.82 --> 7.14 (9)\n presidido\n7.14 --> 7.32 (2)\n la\n7.32 --> 7.46 (4)\n cena\n7.46 --> 7.8 (9)\n inaugural\n7.8 --> 8.02 (2)\n en\n8.02 --> 8.1 (2)\n el\n8.1 --> 8.36 (8)\n Congreso\n8.36 --> 8.68 (7)\n Mundial\n8.68 --> 8.88 (2)\n de\n8.88 --> 9.32 (8)\n Móviles,\n9.6 --> 9.82 (5)\n donde\n9.82 --> 9.98 (2)\n ha\n9.98 --> 10.54 (10)\n codificado\n10.54 --> 10.74 (3)\n con\n10.74 --> 10.94 (2)\n el\n10.94 --> 11.42 (10)\n presidente\n11.42 --> 11.68 (3)\n del\n11.68 --> 12.0 (9)\n gobierno,\n12.06 --> 12.28 (5)\n Pedro\n12.28 --> 12.66 (8)\n Sánchez,\n12.68 --> 12.8 (1)\n y\n12.8 --> 12.9 (2)\n el\n12.9 --> 13.04 (2)\n de\n13.04 --> 13.24 (2)\n la\n13.24 --> 13.78 (12)\n Generalitat,\n13.96 --> 14.02 (4)\n Pera\n14.02 --> 14.38 (9)\n Aragonés.\n18.88 --> 19.12 (7)\n También\n19.12 --> 19.36 (6)\n estuvo\n19.36 --> 19.5 (2)\n la\n19.5 --> 19.8 (9)\n alcaldesa\n19.8 --> 19.92 (2)\n de\n19.92 --> 20.3 (10)\n Barcelona,\n20.38 --> 20.54 (3)\n Ada\n20.54 --> 20.78 (6)\n Colau,\n20.82 --> 20.94 (2)\n ni\n20.94 --> 21.56 (8)\n Aragonés\n21.56 --> 21.8 (2)\n ni\n21.8 --> 22.04 (4)\n ella\n22.04 --> 22.42 (9)\n quisieron\n22.42 --> 22.86 (7)\n recibir\n22.86 --> 23.0 (1)\n o\n23.0 --> 23.28 (5)\n posar\n23.28 --> 23.48 (3)\n con\n23.48 --> 23.8 (6)\n Felipe\n23.8 --> 24.16 (3)\n VI.\n24.68 --> 24.94 (5)\n Desde\n24.94 --> 25.26 (3)\n hoy\n25.26 --> 25.54 (5)\n hasta\n25.54 --> 25.72 (2)\n el\n25.72 --> 26.0 (7)\n jueves,\n26.08 --> 26.18 (2)\n la\n26.18 --> 26.46 (7)\n capital\n26.46 --> 27.0 (8)\n catalana\n27.0 --> 27.26 (5)\n acoge\n27.26 --> 27.42 (2)\n el\n27.42 --> 27.66 (7)\n Mobile,\n27.82 --> 27.98 (3)\n una\n27.98 --> 28.58 (5)\n feria\n28.58 --> 28.88 (3)\n que\n28.88 --> 29.04 (2)\n ya\n29.04 --> 29.16 (2)\n es\n29.16 --> 29.48 (3)\n más\n29.48 --> 29.72 (2)\n de\n29.72 --> 30.28 (10)\n tecnología\n30.28 --> 30.52 (3)\n que\n30.52 --> 30.7 (4)\n solo\n30.7 --> 30.96 (2)\n de\n30.96 --> 31.44 (8)\n móviles.\n31.7 --> 31.8 (2)\n En\n31.8 --> 31.96 (4)\n esta\n31.96 --> 32.42 (7)\n edición\n32.42 --> 32.88 (7)\n todavía\n32.88 --> 33.1 (2)\n no\n33.1 --> 33.26 (2)\n va\n33.26 --> 33.4 (1)\n a\n33.4 --> 33.52 (6)\n llegar\n33.52 --> 33.66 (1)\n a\n33.66 --> 33.84 (3)\n las\n33.84 --> 34.14 (6)\n cifras\n34.14 --> 34.4 (2)\n de\n34.4 --> 34.56 (5)\n antes\n34.56 --> 34.72 (2)\n de\n34.72 --> 34.88 (2)\n la\n34.88 --> 35.28 (9)\n pandemia.\n37.24 --> 37.4 (3)\n Con\n37.4 --> 37.58 (2)\n el\n37.58 --> 37.84 (6)\n Cártel\n37.84 --> 38.04 (2)\n de\n38.04 --> 38.36 (8)\n Completo\n38.36 --> 38.64 (5)\n desde\n38.64 --> 38.92 (4)\n hace\n38.92 --> 39.16 (6)\n varias\n39.16 --> 39.64 (8)\n semanas,\n39.92 --> 39.98 (4)\n para\n39.98 --> 40.2 (4)\n esas\n40.2 --> 40.4 (6)\n fechas\n40.4 --> 40.74 (7)\n estamos\n40.74 --> 41.34 (10)\n completos.\n41.5 --> 41.82 (9)\n Barcelona\n41.82 --> 42.08 (2)\n se\n42.08 --> 42.34 (7)\n prepara\n42.34 --> 42.66 (4)\n para\n42.66 --> 42.94 (7)\n recibir\n42.94 --> 43.14 (2)\n la\n43.14 --> 43.26 (5)\n nueva\n43.26 --> 43.58 (7)\n edición\n43.58 --> 43.8 (3)\n del\n43.8 --> 44.1 (7)\n Mobile.\n44.24 --> 44.36 (7)\n Puestas\n44.36 --> 44.62 (1)\n a\n44.62 --> 45.02 (6)\n punto,\n45.5 --> 45.84 (8)\n personal\n45.84 --> 46.66 (10)\n preparado.\n46.76 --> 46.94 (5)\n Estos\n46.94 --> 47.16 (4)\n días\n47.16 --> 47.4 (3)\n las\n47.4 --> 47.58 (6)\n calles\n47.58 --> 47.74 (2)\n de\n47.74 --> 47.84 (2)\n la\n47.84 --> 48.1 (6)\n ciudad\n48.1 --> 48.52 (8)\n catalana\n48.52 --> 48.72 (2)\n se\n48.72 --> 48.92 (6)\n llenan\n48.92 --> 49.26 (2)\n de\n49.26 --> 49.84 (13)\n congresistas.\n49.92 --> 49.96 (2)\n El\n49.96 --> 50.1 (5)\n hotel\n50.1 --> 50.32 (5)\n tiene\n50.32 --> 51.32 (3)\n 368\n51.32 --> 52.12 (13)\n habitacione ...

# %% [markdown]
# Subtitle generation based on word detail.
#
# **Prompt**:
#
# ```f
# Eres un experto en lengua y subtitulado. El objetivo es crear los subtitulos con su pautado de tiempo a partir de los datos proporcionados. Estos datos son las palabras con su respectivo tiempo de inicio y fin de la mención en un audio. El formato es el siguiente:
# ---
# <tiempo_inicio> --> <tiempo_fin> (<caracteres_por_segundo>)
# <palabra>
# ...
# ---
#
# Genera subtítulos a partir de los datos que se proporcionen. Estos subtítulos deben cumplir los siguientes requerimientos impuestos por la norma UNE de subtitulado.
#     - No romper sintagmas, deben ir en la misma línea:
#         ejemplo: <incorrecto>artículo + sustantivo: el trabajo \n  duro </incorrecto>; <correcto>el trabajo duro </correcto>
#         ejemplo: <incorrecto>sustantivo + adjetivo: de \n  manera urgente </incorrecto>; <correcto>de manera urgente<correcto>.
#     - No separar verbos compuestos en líneas o subtítulos diferentes:
#         ejemplo: </incorrecto>nosotros hemos \n  hecho</incorrecto>; <correcto>nosotros hemos hecho</correcto>.
#     -  A final de línea, no pueden quedar determinantes:
#         ejemplo: <incorrecto>este viernes en la \n  sede </incorrecto>. <correcto>este viernes en la sede. </correcto>.
#     - El máximo de caracteres por línea será 37 caracteres.
#     - El máximo de caracteres por segundo (cps) es de 15.
#
# DATOS:
# ---
# {FORMATTED_WORD_DETAIL_DATA}
# ---
#
# ```

# %%
def txt_a_diccionario_json(txt):
    subtitulos = txt.split('\n')
    diccionario = []
    for i in range(0, len(subtitulos)-1, 2):
        rango_tiempo, palabra_cps = subtitulos[i], subtitulos[i+1].strip()
        inicio, fin = rango_tiempo.split(" --> ")[0], rango_tiempo.split(" --> ")[1].split()[0]
        cps = rango_tiempo[-2]
        palabra = palabra_cps.split("(")[0].strip()
        diccionario.append({'word': palabra, 'start': inicio, 'end': fin, 'cps': cps})
    return diccionario

# %%
words_dict = txt_a_diccionario_json(txt)

# %%
print(words_dict)
